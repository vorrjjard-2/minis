# %% [markdown]
# # Mini 1 - 2010.11929v2 - Visual Transformer
# Faithful implementation of a ViT in `pytorch`.
#
# Dataset : COCO

# %%
from model.model import ViT, VitWrapper

from data.dataset import MiniDataset

from torch.utils.data import DataLoader

import torch
import pytorch_lightning as pl
from pytorch_lightning import trainer

import importlib

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Dataset Handling

# %%
train_dataset = MiniDataset('train')
val_dataset = MiniDataset('valid')
test_dataset = MiniDataset('test')

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)

# %% [markdown]
# ## 2. Training

# %%
vit = ViT()
vit_wrap = VitWrapper(vit)

# %%
trainer = pl.Trainer(
    accelerator='cpu'
    ,max_epochs=100
)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores

# %%
for x, y in train_loader:
    y_hat = vit(x)
    break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 2
#       1 for x, y in train_loader:
# ----> 2     y_hat = vit(x)
#       3     break
#
# File ~/minis/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/minis/venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...
