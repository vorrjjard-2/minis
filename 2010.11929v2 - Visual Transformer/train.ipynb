# %% [markdown]
# <a href="https://colab.research.google.com/github/vorrjjard-2/minis/blob/main/2010.11929v2%20-%20Visual%20Transformer/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini 1 - 2010.11929v2 - Visual Transformer
# Faithful implementation of a ViT in `pytorch`.
#
# Dataset : COCO

# %%
# ONLY RUN ON COLAB RUNTIME
# !git clone https://github.com/vorrjjard-2/minis
# !pip install pytorch_lightning
# Out:
# Cloning into 'minis'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 69 (delta 18), reused 66 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 18.71 KiB | 6.24 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 76.2 MB/s eta 0:00:00
# ...

# %%
cd minis/'2010.11929v2 - Visual Transformer'
# Out:
# /content/minis/2010.11929v2 - Visual Transformer

# %%
from model.model import ViT, VitWrapper

from data.dataset import MiniDataset

from torch.utils.data import DataLoader

import torch
import pytorch_lightning as pl
from pytorch_lightning import trainer

from torch.utils.data import random_split

import importlib

# %%
cd ..
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Dataset Handling

# %%
train_dataset = MiniDataset('train', path='drive/MyDrive/datasets/coco_dataset')
val_dataset = MiniDataset('valid', path='drive/MyDrive/datasets/coco_dataset')
test_dataset = MiniDataset('test', path='drive/MyDrive/datasets/coco_dataset')

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True, num_workers=7)

# %% [markdown]
# ## 2. Training

# %%
vit = ViT()
vit_wrap = VitWrapper(vit)

# %%
trainer = pl.Trainer(
    accelerator='gpu'
    ,max_epochs=100
)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores

# %%
trainer.fit(vit_wrap, train_loader)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name      ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model     │ ViT              │  152 M │ train │     0 │
# │ 1 │ criterion │ CrossEntropyLoss │      0 │ train │     0 │
# └───┴───────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 152 M
# Non-trainable params: 0
# Total params: 152 M
# Total estimated model params size (MB): 609
# Modules in train mode: 139
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# INFO:pytorch_lightning.utilities.rank_zero:
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ERROR:root:Internal Python error in the inspect module.
# ...
