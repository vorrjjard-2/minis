# %% [markdown]
# # Mini 1 - 2010.11929v2 - Visual Transformer
# Faithful implementation of a ViT in `pytorch`.
#
# Dataset : COCO

# %%
# ONLY RUN ON COLAB RUNTIME
# !git clone https://github.com/vorrjjard-2/minis
# !cd minis/'2010.11929v2 - Visual Transformer'
# !pip install pytorch_lightning
# Out:
# Cloning into 'minis'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 55 (delta 15), reused 52 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 13.87 KiB | 6.94 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 13.4 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 38.3 MB/s eta 0:00:00
# ...

# %%
from model.model import ViT, VitWrapper

from data.dataset import MiniDataset

from torch.utils.data import DataLoader

import torch
import pytorch_lightning as pl
from pytorch_lightning import trainer

from torch.utils.data import random_split

import importlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-66490177.py in <cell line: 0>()
# ----> 1 from model.model import ViT, VitWrapper
#       2
#       3 from data.dataset import MiniDataset
#       4
#       5 from torch.utils.data import DataLoader
#
# /content/minis/2010.11929v2 - Visual Transformer/model/model.py in <module>
# ----> 1 from .blocks import PatchEmbedding, EncoderBlock
#       2
#       3 import numpy as np
#       4 import os
#       5 import torch
#
# /content/minis/2010.11929v2 - Visual Transformer/model/blocks.py in <module>
#       5 import cv2
#       6 import torch.nn as nn
# ----> 7 import pytorch_lightning as pl
#       8 import einops
#       9 from einops import rearrange
#
# ModuleNotFoundError: No module named 'pytorch_lightning'
#
# ---------------------------------------------------------------------------
# ...

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Dataset Handling

# %%
train_dataset = MiniDataset('train')
val_dataset = MiniDataset('valid')
test_dataset = MiniDataset('test')

# %%
train_frac =

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)

# %% [markdown]
# ## 2. Training

# %%
vit = ViT()
vit_wrap = VitWrapper(vit)

# %%
trainer = pl.Trainer(
    accelerator='cpu'
    ,max_epochs=100
)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores

# %%
trainer.fit(vit_wrap, train_loader)
# Out:
#   | Name      | Type             | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | model     | ViT              | 152 M  | train | 0
# 1 | criterion | CrossEntropyLoss | 0      | train | 0
# ---------------------------------------------------------------
# 152 M     Trainable params
# 0         Non-trainable params
# 152 M     Total params
# 609.162   Total estimated model params size (MB)
# 139       Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# ...
# Epoch 0:   4%|▎         | 18/507 [00:26<12:11,  0.67it/s, v_num=10, train/loss_step=6.480, train/acc_step=0.125]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
