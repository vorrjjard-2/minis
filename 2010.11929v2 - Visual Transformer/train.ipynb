# %%
from model import Model
# Out:
# Running cells with 'venv (Python 3.13.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/ravisaulog/minis/venv/bin/python -m pip install ipykernel -U --force-reinstall'
